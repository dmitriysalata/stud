# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-работы." data-toc-modified-id="Описание-работы.-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание работы.</a></span></li><li><span><a href="#Изучение-и-предварительная-обработка-данных." data-toc-modified-id="Изучение-и-предварительная-обработка-данных.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Изучение и предварительная обработка данных.</a></span><ul class="toc-item"><li><span><a href="#Описание-данных." data-toc-modified-id="Описание-данных.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Описание данных.</a></span></li><li><span><a href="#Результаты-предварительного-обзора-данных." data-toc-modified-id="Результаты-предварительного-обзора-данных.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Результаты предварительного обзора данных.</a></span></li><li><span><a href="#Предварительная-обработка-данных." data-toc-modified-id="Предварительная-обработка-данных.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Предварительная обработка данных.</a></span><ul class="toc-item"><li><span><a href="#Переименование-колонок." data-toc-modified-id="Переименование-колонок.-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Переименование колонок.</a></span></li><li><span><a href="#Изменение-типов-данных." data-toc-modified-id="Изменение-типов-данных.-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Изменение типов данных.</a></span></li></ul></li></ul></li><li><span><a href="#Задание-функций-для-дальнейшего-расчета." data-toc-modified-id="Задание-функций-для-дальнейшего-расчета.-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Задание функций для дальнейшего расчета.</a></span><ul class="toc-item"><li><span><a href="#Функции-для-анализа-данных" data-toc-modified-id="Функции-для-анализа-данных-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Функции для анализа данных</a></span><ul class="toc-item"><li><span><a href="#Функция-для-создания-пользовательских-профилей." data-toc-modified-id="Функция-для-создания-пользовательских-профилей.-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Функция для создания пользовательских профилей.</a></span></li><li><span><a href="#Функция-для-расчета-удержания." data-toc-modified-id="Функция-для-расчета-удержания.-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Функция для расчета удержания.</a></span></li><li><span><a href="#Функция-для-расчета-конверсии." data-toc-modified-id="Функция-для-расчета-конверсии.-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Функция для расчета конверсии.</a></span></li><li><span><a href="#Функция-для-расчёта-LTV-и-ROI." data-toc-modified-id="Функция-для-расчёта-LTV-и-ROI.-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>Функция для расчёта LTV и ROI.</a></span></li></ul></li><li><span><a href="#Функции-для-визуализации-метрик." data-toc-modified-id="Функции-для-визуализации-метрик.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Функции для визуализации метрик.</a></span><ul class="toc-item"><li><span><a href="#Функция-для-сглаживания-фрейма." data-toc-modified-id="Функция-для-сглаживания-фрейма.-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Функция для сглаживания фрейма.</a></span></li><li><span><a href="#Функция-для-визуализации-удержания" data-toc-modified-id="Функция-для-визуализации-удержания-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Функция для визуализации удержания</a></span></li><li><span><a href="#Функция-для-визуализации-конверсии." data-toc-modified-id="Функция-для-визуализации-конверсии.-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Функция для визуализации конверсии.</a></span></li><li><span><a href="#Функция-для-визуализации-LTV-и-ROI." data-toc-modified-id="Функция-для-визуализации-LTV-и-ROI.-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>Функция для визуализации LTV и ROI.</a></span></li></ul></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Создание-пользовательских-профилей." data-toc-modified-id="Создание-пользовательских-профилей.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Создание пользовательских профилей.</a></span></li><li><span><a href="#Определение-стран-пользователей-и-доли-платящих-из-них." data-toc-modified-id="Определение-стран-пользователей-и-доли-платящих-из-них.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Определение стран пользователей и доли платящих из них.</a></span></li><li><span><a href="#Определение-типов-устройств-пользователей-и-доли-платящих-из-них." data-toc-modified-id="Определение-типов-устройств-пользователей-и-доли-платящих-из-них.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Определение типов устройств пользователей и доли платящих из них.</a></span></li><li><span><a href="#Определение-рекламных-источников-привлечения-пользователей-и-доли-платящих-из-них." data-toc-modified-id="Определение-рекламных-источников-привлечения-пользователей-и-доли-платящих-из-них.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Определение рекламных источников привлечения пользователей и доли платящих из них.</a></span></li><li><span><a href="#Промежуточныые-выводы." data-toc-modified-id="Промежуточныые-выводы.-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Промежуточныые выводы.</a></span></li></ul></li><li><span><a href="#Маркетинг." data-toc-modified-id="Маркетинг.-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Маркетинг.</a></span><ul class="toc-item"><li><span><a href="#Общая-сумма-расходов-по-источникам,-распределение-по-источникам." data-toc-modified-id="Общая-сумма-расходов-по-источникам,-распределение-по-источникам.-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Общая сумма расходов по источникам, распределение по источникам.</a></span></li><li><span><a href="#Средняя-стоимость-привлечения-пользователя." data-toc-modified-id="Средняя-стоимость-привлечения-пользователя.-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Средняя стоимость привлечения пользователя.</a></span></li><li><span><a href="#Промежуточные-выводы-по-результатам-рассмотрения-трат-на-маркетинг." data-toc-modified-id="Промежуточные-выводы-по-результатам-рассмотрения-трат-на-маркетинг.-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Промежуточные выводы по результатам рассмотрения трат на маркетинг.</a></span></li></ul></li><li><span><a href="#Оценка-окупаемости-рекламы." data-toc-modified-id="Оценка-окупаемости-рекламы.-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Оценка окупаемости рекламы.</a></span><ul class="toc-item"><li><span><a href="#Окупаемость-рекламы." data-toc-modified-id="Окупаемость-рекламы.-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Окупаемость рекламы.</a></span><ul class="toc-item"><li><span><a href="#Рассмотрение-общей-окупаемости-рекламы.¶" data-toc-modified-id="Рассмотрение-общей-окупаемости-рекламы.¶-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Рассмотрение общей окупаемости рекламы.¶</a></span></li><li><span><a href="#Рассмотрение-окупаемости-рекламы-с-разбивкой-на-каналы." data-toc-modified-id="Рассмотрение-окупаемости-рекламы-с-разбивкой-на-каналы.-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>Рассмотрение окупаемости рекламы с разбивкой на каналы.</a></span></li><li><span><a href="#Рассмотрение-окупаемости-рекламы-с-разбивкой-на-страны." data-toc-modified-id="Рассмотрение-окупаемости-рекламы-с-разбивкой-на-страны.-6.1.3"><span class="toc-item-num">6.1.3&nbsp;&nbsp;</span>Рассмотрение окупаемости рекламы с разбивкой на страны.</a></span></li><li><span><a href="#Рассмотрение-окупаемости-рекламы-с-разбивкой-на-используемые-пользователями-устройства." data-toc-modified-id="Рассмотрение-окупаемости-рекламы-с-разбивкой-на-используемые-пользователями-устройства.-6.1.4"><span class="toc-item-num">6.1.4&nbsp;&nbsp;</span>Рассмотрение окупаемости рекламы с разбивкой на используемые пользователями устройства.</a></span></li><li><span><a href="#Промежуточные-выводы-по-рассмотрению-окупаемости-рекламы." data-toc-modified-id="Промежуточные-выводы-по-рассмотрению-окупаемости-рекламы.-6.1.5"><span class="toc-item-num">6.1.5&nbsp;&nbsp;</span>Промежуточные выводы по рассмотрению окупаемости рекламы.</a></span></li></ul></li><li><span><a href="#Конверсия-и-удержание." data-toc-modified-id="Конверсия-и-удержание.-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Конверсия и удержание.</a></span><ul class="toc-item"><li><span><a href="#Рассмотрение-конверсии-и-удержания-с-разбивкой-по-устройствам." data-toc-modified-id="Рассмотрение-конверсии-и-удержания-с-разбивкой-по-устройствам.-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Рассмотрение конверсии и удержания с разбивкой по устройствам.</a></span></li><li><span><a href="#Рассмотрение-конверсии-и-удержания-с-разбивкой-по-странам." data-toc-modified-id="Рассмотрение-конверсии-и-удержания-с-разбивкой-по-странам.-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>Рассмотрение конверсии и удержания с разбивкой по странам.</a></span></li><li><span><a href="#Рассмотрение-конверсии-и-удержания-с-разбивкой-по-рекламным-каналам." data-toc-modified-id="Рассмотрение-конверсии-и-удержания-с-разбивкой-по-рекламным-каналам.-6.2.3"><span class="toc-item-num">6.2.3&nbsp;&nbsp;</span>Рассмотрение конверсии и удержания с разбивкой по рекламным каналам.</a></span></li><li><span><a href="#Промежуточные-выводы-по-результатам-рассмотрения-данных-по-конверсии-и-удержанию-пользователей." data-toc-modified-id="Промежуточные-выводы-по-результатам-рассмотрения-данных-по-конверсии-и-удержанию-пользователей.-6.2.4"><span class="toc-item-num">6.2.4&nbsp;&nbsp;</span>Промежуточные выводы по результатам рассмотрения данных по конверсии и удержанию пользователей.</a></span></li></ul></li></ul></li><li><span><a href="#Выводы." data-toc-modified-id="Выводы.-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Выводы.</a></span><ul class="toc-item"><li><span><a href="#Причины-неэффективности-привлечения-пользователей." data-toc-modified-id="Причины-неэффективности-привлечения-пользователей.-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Причины неэффективности привлечения пользователей.</a></span></li><li><span><a href="#Рекомендации-для-отдела-маркетинга." data-toc-modified-id="Рекомендации-для-отдела-маркетинга.-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Рекомендации для отдела маркетинга.</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Описание работы.

# %% [markdown]
# Имеется лог сервера с данными о посещениях приложения новыми пользователями, зарегистрировавшимися в период с 2019-05-01 по 2019-10-27, выгрузка их покупок за этот период, а также статистика рекламных расходов. Необходимо изучить, как люди пользуются продуктом, когда они начинают покупать, сколько денег приносит каждый клиент, когда он окупается и какие факторы отрицательно влияют на привлечение пользователей.
#
# Загрузим необходимые в дальнейшей работе библиотеки:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from datetime import datetime, timedelta
pd.set_option('display.float_format', '{:.4f}'.format)

# %% [markdown]
# # Изучение и предварительная обработка данных.

# %% [markdown]
# Загрузим имеющиеся датасеты с рассмотрением их первых 5 строк:

# %%
try:
    visits = pd.read_csv('C:/projects/project_6/visits_info_short.csv')
except:
    visits = pd.read_csv('/datasets/visits_info_short.csv')
visits.head()
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40

# %%
try:
    orders = pd.read_csv('C:/projects/project_6/orders_info_short.csv')
except:
    orders = pd.read_csv('/datasets/orders_info_short.csv')
orders.head()
# Out:
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52   4.9900
# 1  174361394180  2019-05-01 12:24:04   4.9900
# 2  529610067795  2019-05-01 11:34:04   4.9900
# 3  319939546352  2019-05-01 15:34:40   4.9900
# 4  366000285810  2019-05-01 13:59:51   4.9900

# %%
try:
    costs = pd.read_csv('C:/projects/project_6/costs_info_short.csv')
except:
    costs = pd.read_csv('/datasets/costs_info_short.csv')
costs.head()
# Out:
#            dt   Channel    costs
# 0  2019-05-01  FaceBoom 113.3000
# 1  2019-05-02  FaceBoom  78.1000
# 2  2019-05-03  FaceBoom  85.8000
# 3  2019-05-04  FaceBoom 136.4000
# 4  2019-05-05  FaceBoom 122.1000

# %% [markdown]
# Рассмотрим информацию о представленных датасетах:

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %%
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# ## Описание данных.
# Таблица visits (лог сервера с информацией о посещениях сайта):
#
#     - User Id — уникальный идентификатор пользователя
#     - Device — категория устройства пользователя
#     - Session start — дата и время начала сессии
#     - Session End — дата и время окончания сессии
#     - Channel — идентификатор рекламного источника, из которого пришел пользователь
#     - Region - страна пользователя
#
# Таблица orders (информация о заказах):
#
#     - User Id — уникальный id пользователя, который сделал заказ
#     - Event Dt — дата и время покупки
#     - Revenue — выручка
#
# Таблица costs (информация о затратах на маркетинг):
#
#     - Channel — идентификатор рекламного источника
#     - Dt — дата
#     - Costs — затраты на этот рекламный источник в этот день

# %% [markdown]
# ## Результаты предварительного обзора данных.

# %% [markdown]
# - для удобства дальнейшей работы целесообразно изменение наименований столбцов с заменой заглавных букв на строчные, а пробелов на нижнее подчеркивание;
# - пропусков в таблицах нет;
# - необходимо изменение типа данных на datetime столбцов Session Start, Session End таблицы visits, Event Dt таблицы orders, Dt таблицы costs.

# %% [markdown]
# ## Предварительная обработка данных.

# %% [markdown]
# ### Переименование колонок.

# %% [markdown]
# Приведем наименования колонок таблиц к единому стилю:

# %%
visits.columns = [x.lower().replace(' ', '_') for x in visits.columns]
orders.columns = [x.lower().replace(' ', '_') for x in orders.columns]
costs.columns = [x.lower().replace(' ', '_') for x in costs.columns]

# %% [markdown]
# ### Изменение типов данных.

# %% [markdown]
# Изменим тип данных в соответствии с п. 2.2.:

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB

# %%
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB

# %%
costs['dt'] = pd.to_datetime(costs['dt']).dt.date
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# Выполним проверку датафреймов на наличие дубликатов с определением их доли в датафреймах:

# %%
visits.duplicated().mean()
# Out:
# 0.0

# %%
orders.duplicated().mean()
# Out:
# 0.0

# %% [markdown]
# **В исследуемых датафреймах отсутствуют дубликаты.**

# %% [markdown]
# # Задание функций для дальнейшего расчета.

# %% [markdown]
# ## Функции для анализа данных

# %% [markdown]
# ### Функция для создания пользовательских профилей.

# %%
def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# ### Функция для расчета удержания.

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчета конверсии.

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчёта LTV и ROI.

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ## Функции для визуализации метрик.

# %% [markdown]
# ### Функция для сглаживания фрейма.

# %%
def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ### Функция для визуализации удержания

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации конверсии.

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации LTV и ROI.

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Исследовательский анализ данных

# %% [markdown]
# ## Создание пользовательских профилей.

# %% [markdown]
# Используя имеющуюся функцию, создадим датафрейм с информацией о профилях пользователей:

# %%
users_profiles = get_profiles(visits, orders, costs)
users_profiles.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True            1.0882
# 1  2019-07-09 2019-07-01  False            1.1072
# 2  2019-10-01 2019-10-01  False            0.0000
# 3  2019-08-22 2019-08-01  False            0.9882
# 4  2019-10-02 2019-10-01  False            0.2308

# %% [markdown]
# Определим минимальную и максимальную даты привлечения пользователей:

# %%
min(users_profiles['dt'])
# Out:
# datetime.date(2019, 5, 1)

# %%
max(users_profiles['dt'])
# Out:
# datetime.date(2019, 10, 27)

# %% [markdown]
# **Минимальная и максимальная даты соответствуют заданию к проектной работе, таким образом дополнительная фильтрация датафреймов не требуется.**

# %% [markdown]
# ## Определение стран пользователей и доли платящих из них.

# %%
country_payers = (
    users_profiles
    .groupby(by='region')
    .agg({'user_id':'count','payer':'mean'})
    .sort_values('payer',ascending=False)
    .style
    .format({'payer': '{:.4f}'})
)
country_payers
# Out:
# <style  type="text/css" >
# </style><table id="T_1b5c3_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >user_id</th>        <th class="col_heading level0 col1" >payer</th>    </tr>    <tr>        <th class="index_name level0" >region</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1b5c3_level0_row0" class="row_heading level0 row0" >United States</th>
#                         <td id="T_1b5c3_row0_col0" class="data row0 col0" >100002</td>
#                         <td id="T_1b5c3_row0_col1" class="data row0 col1" >0.0690</td>
#             </tr>
#             <tr>
#                         <th id="T_1b5c3_level0_row1" class="row_heading level0 row1" >Germany</th>
#                         <td id="T_1b5c3_row1_col0" class="data row1 col0" >14981</td>
# ...

# %% [markdown]
# ## Определение типов устройств пользователей и доли платящих из них.

# %%
devices_payers = (
    users_profiles
    .groupby(by='device')
    .agg({'user_id':'count','payer':'mean'})
    .sort_values('payer',ascending=False)
    .style
    .format({'payer': '{:.4f}'})
)
devices_payers
# Out:
# <style  type="text/css" >
# </style><table id="T_8c607_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >user_id</th>        <th class="col_heading level0 col1" >payer</th>    </tr>    <tr>        <th class="index_name level0" >device</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8c607_level0_row0" class="row_heading level0 row0" >Mac</th>
#                         <td id="T_8c607_row0_col0" class="data row0 col0" >30042</td>
#                         <td id="T_8c607_row0_col1" class="data row0 col1" >0.0636</td>
#             </tr>
#             <tr>
#                         <th id="T_8c607_level0_row1" class="row_heading level0 row1" >iPhone</th>
#                         <td id="T_8c607_row1_col0" class="data row1 col0" >54479</td>
#                         <td id="T_8c607_row1_col1" class="data row1 col1" >0.0621</td>
# ...

# %% [markdown]
# ## Определение рекламных источников привлечения пользователей и доли платящих из них.

# %%
advert_payers = (
    users_profiles
    .groupby(by='channel')
    .agg({'user_id':'count','payer':'mean'})
    .sort_values('payer',ascending=False)
    .style
    .format({'payer': '{:.4f}'})
)
advert_payers
# Out:
# <style  type="text/css" >
# </style><table id="T_4a853_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >user_id</th>        <th class="col_heading level0 col1" >payer</th>    </tr>    <tr>        <th class="index_name level0" >channel</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4a853_level0_row0" class="row_heading level0 row0" >FaceBoom</th>
#                         <td id="T_4a853_row0_col0" class="data row0 col0" >29144</td>
#                         <td id="T_4a853_row0_col1" class="data row0 col1" >0.1220</td>
#             </tr>
#             <tr>
#                         <th id="T_4a853_level0_row1" class="row_heading level0 row1" >AdNonSense</th>
#                         <td id="T_4a853_row1_col0" class="data row1 col0" >3880</td>
# ...

# %% [markdown]
# ## Промежуточныые выводы.

# %% [markdown]
# В соответствии с таблицами, представленными в пунктах 4.2 - 4.4 можно отметить следующее:
# - доля платящих пользователей в США значительно выше по сравнению с другими представленными странами (6.9% для США, для остальных стран (Великобритания, Германия, Франция) доля платящих составляет 3.8 - 4.1%);
# - в распределении доли платящих пользователей в зависимости от типа используемого устройства выделяется отставание пользователей, использующих PC - доля платящих пользователей среди них составила 5%, в то время как для MAC и IPhone доли таких пользователей составили 6.4 и 6.2 % соответственно;
# - рассмотрение долей платящих пользователей в зависимости от использованного при привлечении пользователей канала рекламы выделяются как наиболее эффективные FaceBoom (12.2% платящих пользователей), AdNonSense (11.3%), lambdaMediaAds (10.5%); наименее эффективные - MediaTornado (3.8%), LeapBob (3.1%), OppleCreativeMedia (2.7%) - их доли платящих пользователей близки к доле среди клиентов, пришедших без использования рекламы (2.1%).

# %% [markdown]
# # Маркетинг.

# %% [markdown]
# ## Общая сумма расходов по источникам, распределение по источникам.

# %% [markdown]
# Соберем датафрейм с данными по тратам на маркетинг:

# %%
cac = (
    users_profiles[['user_id','dt','acquisition_cost','channel']]
    .drop_duplicates()
)

cac.head()
# Out:
#     user_id          dt  acquisition_cost     channel
# 0    599326  2019-05-07            1.0882    FaceBoom
# 1   4919697  2019-07-09            1.1072    FaceBoom
# 2   6085896  2019-10-01            0.0000     organic
# 3  22593348  2019-08-22            0.9882  AdNonSense
# 4  31989216  2019-10-02            0.2308     YRabbit

# %% [markdown]
# Определим общую сумму, потраченную на рекламу:

# %%
sum_cac = sum(cac['acquisition_cost'])
sum_cac
# Out:
# 105497.30000001584

# %% [markdown]
# Сгруппируем траты на рекламу по ее источникам:

# %%
cac_grouped_channel = (
            cac.groupby('channel')
            .agg({'acquisition_cost': 'sum'})
            .rename(columns={'acquisition_cost': 'cac'})
            .sort_values('cac',ascending=False)
        )
cac_grouped_channel
# Out:
#                           cac
# channel
# TipTop             54751.3000
# FaceBoom           32445.6000
# WahooNetBanner      5151.0000
# AdNonSense          3911.2500
# OppleCreativeMedia  2151.2500
# RocketSuperAds      1833.0000
# LeapBob             1797.6000
# lambdaMediaAds      1557.6000
# MediaTornado         954.4800
# YRabbit              944.2200
# organic                0.0000

# %% [markdown]
# Выведем на график траты на рекламу в зависимости от времени:

# %%
costs.groupby('dt').agg({'costs':'sum'}).rolling(7).mean().plot(grid=True,figsize=(15,8))
plt.legend()
plt.xlabel('Даты')
plt.ylabel('Величина CAC в день')
plt.title('Изменение CAC со временем');

# %% [markdown]
# ## Средняя стоимость привлечения пользователя.

# %% [markdown]
# Определим общую среднюю стоимость привлечения пользователей (для корректности расчета исключим из таблицы профилей клиентов, привлеченных без использования рекламы):

# %%
cac_disorganic = cac.query('channel != "organic"')
cac_disorganic
# Out:
#              user_id          dt  acquisition_cost       channel
# 0             599326  2019-05-07            1.0882      FaceBoom
# 1            4919697  2019-07-09            1.1072      FaceBoom
# 3           22593348  2019-08-22            0.9882    AdNonSense
# 4           31989216  2019-10-02            0.2308       YRabbit
# 7           46006712  2019-06-30            1.0080    AdNonSense
# ...              ...         ...               ...           ...
# 149999  999942424543  2019-05-24            1.9000        TipTop
# 150001  999949280903  2019-08-12            1.1178      FaceBoom
# 150003  999956196527  2019-09-28            3.5000        TipTop
# 150005  999976332130  2019-07-23            2.6000        TipTop
# 150006  999979924135  2019-09-28            0.2057  MediaTornado
#
# [93569 rows x 4 columns]

# %%
avg_user_cost = cac_disorganic['acquisition_cost'].mean()
avg_user_cost
# Out:
# 1.1274813239427588

# %% [markdown]
# Выполним тоже самое для различных источников траффика:

# %%
avg_grouped_cost = (
            cac_disorganic.groupby('channel')
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'mean_cac'})
            .sort_values('mean_cac',ascending=False)
        )
avg_grouped_cost
# Out:
#                     mean_cac
# channel
# TipTop                2.7990
# FaceBoom              1.1133
# AdNonSense            1.0081
# lambdaMediaAds        0.7248
# WahooNetBanner        0.6022
# RocketSuperAds        0.4121
# OppleCreativeMedia    0.2500
# YRabbit               0.2190
# MediaTornado          0.2187
# LeapBob               0.2102

# %% [markdown]
# ## Промежуточные выводы по результатам рассмотрения трат на маркетинг.

# %% [markdown]
# По представленным общим сведениям о расходах на маркетинг отмечаем:
# - значительную часть трат составили средства использованные на каналы TipTop (54751.30 из 105497.3, т.е. более половины) и FaceBoom (32445.6 из 105497.3, т.е. порядка 30%);
# - средства, которые тратятся на маркетинг со временем растут (ежедневные траты на маркетинг за период с мая по октябрь выросли более чем в 2 раза);
# - средства, потраченные на пользователя с использованием TipTop, более чем в два раза превышают среднюю стоимость привлечения клиента (2.8 проти 1.12), при этом средства, потраченные на привлечение пользователей с использованием других каналов меньше средней стоимости.

# %% [markdown]
# # Оценка окупаемости рекламы.

# %% [markdown]
# ## Окупаемость рекламы.

# %% [markdown]
# ### Рассмотрение общей окупаемости рекламы.¶

# %% [markdown]
# Для рассмотрения общей окупаемости рекламы, вызовем функции для расчета и визуализации LTV, ROI, CAC.

# %% [markdown]
# Исключим из проводимого анализа пользователей, которые были привлечены без использования рекламы ("organic"):

# %%
users_profiles = users_profiles.query('channel != "organic"')

# %%
observation_date = datetime(2019, 11, 5).date()
ltv_roi_raw, ltv_grouped, ltv_in_time, roi_grouped, roi_in_time = get_ltv(
    users_profiles,
    orders,
    observation_date,
    14,
    dimensions=[]
    )

# %%
plot_ltv_roi(ltv_grouped, ltv_in_time, roi_grouped, roi_in_time, 14, window=7)

# %% [markdown]
# ### Рассмотрение окупаемости рекламы с разбивкой на каналы.

# %% [markdown]
# Для рассмотрения общей окупаемости рекламы, вызовем функции для расчета и визуализации LTV, ROI, CAC с разбивкой по каналам привлечения пользователей.

# %%
ltv_ch_roi_raw, ltv_ch_grouped, ltv_ch_in_time, roi_ch_grouped, roi_ch_in_time = get_ltv(
    users_profiles,
    orders,
    observation_date,
    14,
    dimensions=['channel']
    )

# %%
plot_ltv_roi(ltv_ch_grouped, ltv_ch_in_time, roi_ch_grouped, roi_ch_in_time, 14, window=7)

# %% [markdown]
# Для лучшей читаемости графиков, выберем для рассмотрения 4 канала отобранных по средней стоимости - 2 самых дорогих (TipTop и FaceBoom), самый дешевый (LeapBob) и средний по стоимости (WahooNetBanner).

# %%
channels = ['TipTop','FaceBoom','LeapBob','WahooNetBanner']
users_channels = users_profiles.query('channel == @channels')

# %%
ltv_ch1_roi_raw, ltv_ch1_grouped, ltv_ch1_in_time, roi_ch1_grouped, roi_ch1_in_time = get_ltv(
    users_channels,
    orders,
    observation_date,
    14,
    dimensions=['channel']
    )

# %%
plot_ltv_roi(ltv_ch1_grouped, ltv_ch1_in_time, roi_ch1_grouped, roi_ch1_in_time, 14, window=7)

# %% [markdown]
# ### Рассмотрение окупаемости рекламы с разбивкой на страны.

# %% [markdown]
# Для рассмотрения общей окупаемости рекламы, вызовем функции для расчета и визуализации LTV, ROI, CAC с разбивкой по странам пользователей.

# %%
ltv_rg_roi_raw, ltv_rg_grouped, ltv_rg_in_time, roi_rg_grouped, roi_rg_in_time = get_ltv(
    users_profiles,
    orders,
    observation_date,
    14,
    dimensions=['region']
    )

# %%
plot_ltv_roi(ltv_rg_grouped, ltv_rg_in_time, roi_rg_grouped, roi_rg_in_time, 14, window=7)

# %% [markdown]
# Для лучшей читаемости графиков, выберем для рассмотрения 2 страны - США, выделяющуюся как не окупающуюся и Великобританию (остальные страны близки по уровню окупаемости, поэтому можно взять любую).

# %%
countries = ['United States','UK']
users_countries = users_profiles.query('region == @countries')

# %%
ltv_rg1_roi_raw, ltv_rg1_grouped, ltv_rg1_in_time, roi_rg1_grouped, roi_rg1_in_time = get_ltv(
    users_countries,
    orders,
    observation_date,
    14,
    dimensions=['region']
    )

# %%
plot_ltv_roi(ltv_rg1_grouped, ltv_rg1_in_time, roi_rg1_grouped, roi_rg1_in_time, 14, window=7)

# %% [markdown]
# ### Рассмотрение окупаемости рекламы с разбивкой на используемые пользователями устройства.

# %% [markdown]
# Для рассмотрения общей окупаемости рекламы, вызовем функции для расчета и визуализации LTV, ROI, CAC с разбивкой по устройствам пользователей.

# %%
ltv_dv_roi_raw, ltv_dv_grouped, ltv_dv_in_time, roi_dv_grouped, roi_dv_in_time = get_ltv(
    users_profiles,
    orders,
    observation_date,
    14,
    dimensions=['device']
    )

# %%
plot_ltv_roi(ltv_dv_grouped, ltv_dv_in_time, roi_dv_grouped, roi_dv_in_time, 14, window=7)

# %% [markdown]
# ### Промежуточные выводы по рассмотрению окупаемости рекламы.

# %% [markdown]
# Представленные графики по окупаемости рекламы показывают следующее:
# - реклама перестала в целом окупаться во второй половине июня, что произошло в следствие резкого роста стоимости рекламы в первой половине июня;
# - средняя стоимость привлечения пользователей с использованием TipTop заметно ступенчато растет, что и стало основной причиной роста общих трат на маркетинг;
# - также отмечается, что траты на второй по полпулярности источник привлечения платящих пользователей FaceBoom также не окупаем;
# - стоимость привлечения пользователей из США также показала заметный рост, что говорит о том, что TipTop является средством привлечения клиентов в первую очередь из США;
# - несмотря на более высокий показатель LTV пользователей из США, по причине высоких трат на маркетинг при привлечении данных пользователей, они не окупаемы с июня 2019. Также в июне произошло заметное снижение трат на маркетинг для остальных стран;
# - худшая окупаемость отмечается для пользователей, использующих iPhone и Mac.

# %% [markdown]
# ## Конверсия и удержание.

# %% [markdown]
# ### Рассмотрение конверсии и удержания с разбивкой по устройствам.

# %% [markdown]
# Для рассмотрения конверсии и удержания, вызовем функции для их расчета и визуализации с разбивкой по устройствам.

# %%
ret_dv_raw, ret_dv_grouped, ret_dv_in_time = get_retention(
    users_profiles,
    visits,
    observation_date,
    14,
    dimensions=['device']
)

# %%
plot_retention(ret_dv_grouped, ret_dv_in_time, 14, window=7)

# %%
conv_dv_raw, conv_dv_grouped, conv_dv_in_time = get_conversion(
    users_profiles,
    orders,
    observation_date,
    14,
    dimensions=['device']
)

# %%
plot_conversion(conv_dv_grouped, conv_dv_in_time, 14, window=7)

# %% [markdown]
# ### Рассмотрение конверсии и удержания с разбивкой по странам.

# %% [markdown]
# Для рассмотрения конверсии и удержания, вызовем функции для их расчета и визуализации с разбивкой по странам.

# %%
ret_rg_raw, ret_rg_grouped, ret_rg_in_time = get_retention(
    users_profiles,
    visits,
    observation_date,
    14,
    dimensions=['region']
)

# %%
plot_retention(ret_rg_grouped, ret_rg_in_time, 14, window=7)

# %%
conv_rg_raw, conv_rg_grouped, conv_rg_in_time = get_conversion(
    users_profiles,
    orders,
    observation_date,
    14,
    dimensions=['region']
)

# %%
plot_conversion(conv_rg_grouped, conv_rg_in_time, 14, window=7)

# %% [markdown]
# ### Рассмотрение конверсии и удержания с разбивкой по рекламным каналам.

# %% [markdown]
# Для рассмотрения конверсии и удержания, вызовем функции для их расчета и визуализации с разбивкой по рекламным каналам.

# %%
ret_ch_raw, ret_ch_grouped, ret_ch_in_time = get_retention(
    users_profiles,
    visits,
    observation_date,
    14,
    dimensions=['channel']
)

# %%
plot_retention(ret_ch_grouped, ret_ch_in_time, 5, window=7)

# %%
conv_ch_raw, conv_ch_grouped, conv_ch_in_time = get_conversion(
    users_profiles,
    orders,
    observation_date,
    14,
    dimensions=['channel']
)

# %%
plot_conversion(conv_ch_grouped, conv_ch_in_time, 14, window=7)

# %% [markdown]
# ### Промежуточные выводы по результатам рассмотрения данных по конверсии и удержанию пользователей.

# %% [markdown]
# По представленным графикам мы можем отметить:
# - тип используемого устройства не оказывает влияния на величины конверсии и удержания пользователей;
# - конверсия и удержание выделяются для пользователей из США - для них характерны большие значения конверсии, но при этом низкие значения удержания;
# - следует отметить крайне низкие (ниже, чем у "органических" пользователей) показатели удержания пользователей, привлеченных с использованием FaceBoom, с учетом высокой доли конверсии данных пользователей, низкое их удержание может быть одной из основных причин общих неудовлетворительных показателей окупаемости. Определение причин указанного тренда требует проведения дополнительного углубленного анализа с привлечением данных по использованию приложения пользователями, привлеченными на FaceBoom.

# %% [markdown]
# # Выводы.

# %% [markdown]
# ## Причины неэффективности привлечения пользователей.

# %% [markdown]
# В качестве основных причин неудовлетворительной эффективности привлечения пользователей мы можем назвать:
# - высокие траты на маркетинг с использованием TipTop, что заметно отражается на общей окупаемости;
# - крайне низкие показатели удержания пользователей, привлеченных на FaceBoom, что приводит к их неокупаемости.

# %% [markdown]
# ## Рекомендации для отдела маркетинга.

# %% [markdown]
# По результатам проведенного анализ, в качестве рекомендаций для отдела маркетинга целесообразно предложить:
# - снижение расходов на привлечение пользователей через TipTop с одновременным равномерным распределением освобождающихся средств на другие каналы привлечения пользователей (при этом на FaceBoom увеличение трат возможно только по результатам определения и устранения причин низкого удержания пользователей в соответствии со следующим пунктом);
# - инициировать проведение дополнительного углубленного анализ пользовательского поведения для клиентов, привлеченных с использованием FaceBoom для определения причин и возможности их устранения низких показателей удержания.
